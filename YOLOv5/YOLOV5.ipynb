# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

# %%
# !nvidia-smi
# Out:
# Mon Apr 24 23:42:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
# !python drive/MyDrive/Project3/yolov5/train.py --img 640 --batch 16 --epochs 10 --data foreign_object.yaml --weights /content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object5/weights/best.pt --name yolo_foreign_object_ml_project_final_7 --cache
# Out:
# 2023-04-24 23:42:30.130086: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 23:42:31.403786: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python drive/MyDrive/Project3/yolov5/detect.py --img 640 --weights /content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_ml_project_final_1/weights/best.pt --source ../dataset/images/test --name yolo_det_final
# Out:
# detect: weights=['/content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_ml_project_final_1/weights/best.pt'], source=../dataset/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolo_det_final, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-17-g7845cea Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86180143 parameters, 0 gradients, 203.8 GFLOPs
# image 1/377 /content/drive/MyDrive/Project3/dataset/images/test/00008.jpg: 640x640 1 foreign-object, 80.2ms
# image 2/377 /content/drive/MyDrive/Project3/dataset/images/test/00009.jpg: 640x544 1 foreign-object, 86.6ms
# ...

# %%
# !python drive/MyDrive/Project3/yolov5/val.py  --img 640 --weights /content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_ml_project_final_1/weights/best.pt --data foreign_object.yaml --task test
# Out:
# val: data=/content/drive/MyDrive/Project3/yolov5/data/foreign_object.yaml, weights=['/content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_ml_project_final_1/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-17-g7845cea Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86180143 parameters, 0 gradients, 203.8 GFLOPs
# test: Scanning /content/drive/MyDrive/Project3/dataset/labels/val.cache... 376 images, 0 backgrounds, 0 corrupt: 100% 376/376 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 12/12 [00:53<00:00,  4.44s/it]
# ...
